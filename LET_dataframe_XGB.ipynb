# %% [markdown]
# This notebook makes a dataframe for inputs (target and feature variables) from the Large Ensemble Testbed (LET) based on SOCAT and USV Saildrone sampling in the Southern Ocean (Section I). Sampling masks can be found in the repository. First, the direct effect of temperature is removed from pCO2 (pCO2-T), with the resulting pCO2-Residual. The code for this calculation is found in a different notebook in the repository ("calculate_pco2_components"). Then, the XGBoost algorithm reconstructs the surface ocean pCO2-Residual in time and space equivalent to the LET output (1982-2016) (Section II). Finally, pCO2-T is added back to the pCO2-Residual to get pCO2 (Section III).
#
# This notebook was originally created by Val Bennington, and modified by Thea Hatlen Heimdal.

# %%
import os
import datetime
from pathlib import Path
from collections import defaultdict
import scipy
import random
import numpy as np
import xarray as xr
import pandas as pd
import joblib
import pickle

# machine learning libraries
import sklearn            # machine-learning libary with many algorithms implemented
import xgboost as xgb     # extreme gradient boosting (XGB)
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

# Python file with supporting functions
import pre_saildrone_5

# %% [markdown]
# ### <font color='red'>Section I</font>
# #### Make dataframe for inputs for XGB algorithm

# %%
# Accessing directories

root_dir = "/data/artemis/workspace/theimdal/saildrone_5"
# Path to the dataframe created in this notebook
data_output_dir = f"{root_dir}/LET_selected_XGB" 

# Path to pickle file with list of LET members
reference_output_dir = "/data/artemis/workspace/theimdal/saildrone/LET_pickle_files" 

# Path to "raw" LET output
ensemble_dir_head = "/local/data/artemis/simulations/LET"

# %%
# Loading references to "pick" members from the LET
# We use 75 members in total, 25 each from CESM, CanESM2 and GFDL
# "mems_dict" is a list of the members of the LET

path_LET = f"{reference_output_dir}/members_LET_dict.pickle"
path_seeds = f"{reference_output_dir}/random_seeds.npy"
path_loc = f"{reference_output_dir}/members_seed_loc_dict.pickle"
with open(path_LET,'rb') as handle:
    mems_dict = pickle.load(handle)
    random_seeds = np.load(path_seeds)
    with open(path_loc,'rb') as handle:
        seed_loc_dict = pickle.load(handle)

# %%
mems_dict
# Out:
# {'CESM': ['001',
#   '002',
#   '009',
#   '010',
#   '011',
#   '012',
#   '013',
#   '014',
#   '015',
#   '016',
#   '017',
#   '018',
#   '020',
#   '021',
#   '023',
#   '024',
#   '025',
#   '030',
#   '031',
#   '034',
#   '035',
#   '101',
#   '102',
#   '103',
#   '104'],
#  'GFDL': ['01',
#   '02',
#   '03',
#   '04',
#   '05',
#   '06',
#   '08',
#   '09',
#   '10',
#   '11',
#   '12',
#   '13',
#   '14',
#   '16',
#   '17',
#   '18',
#   '19',
#   '20',
#   '22',
#   '23',
#   '26',
#   '27',
#   '28',
#   '29',
#   '30'],
#  'CanESM2': ['r1r10',
#   'r1r9',
#   'r3r1',
#   'r4r5',
#   'r5r10',
#   'r2r1',
#   'r3r2',
#   'r3r9',
#   'r4r6',
#   'r5r2',
#   'r1r6',
#   'r2r2',
#   'r3r4',
#   'r4r1',
#   'r4r7',
#   'r5r4',
#   'r1r7',
#   'r3r6',
#   'r4r8',
#   'r5r5',
#   'r2r8',
#   'r3r7',
#   'r4r3',
#   'r5r1',
#   'r5r9']}

# %%
# Setting the date range to unify the date type
# The LET output ranges from 1982-2017

# Define date range
date_range_start = '1982-01-01T00:00:00.000000000'
date_range_end = '2017-01-01T00:00:00.000000000'

# create date vector
dates = pd.date_range(start=date_range_start, 
                      end=date_range_end,freq='MS') + np.timedelta64(14, 'D')

# %%
# "pre_saildrone_5" is a python file with supporting functions
# This creates a dataframe with all inputs (features and target variables) needed for the machine learning

for ens, mem_list in mems_dict.items(): 
    print(ens)
    for member in mem_list:
        print(member)
        
        df = pre_saildrone_5.create_inputs(ensemble_dir_head, ens, member, dates)
    
        # Save the pandas data frame to my workspace
        pre_saildrone_5.save_clean_data(df, data_output_dir, ens, member)
        #del df

# %% [markdown]
# ### <font color='red'>Section II</font>
# #### For Machine Learning

# %%
# Accessing directories

root_dir = "/local/data/artemis/workspace/theimdal/saildrone_5"

data_output_dir = f"{root_dir}/LET_selected_XGB"

model_output_dir = f"{root_dir}/models/trained"
recon_output_dir = f"{root_dir}/models/reconstructions"
other_output_dir = f"{root_dir}/models/performance_metrics"

approach = 'xg'
approach_output_dir = f"{other_output_dir}/{approach}"

reference_output_dir = "/data/artemis/workspace/theimdal/saildrone/LET_pickle_files"

# =========================================
# Number of cores you have access to for model training
# =========================================
jobs = 30

# %%
# Loading references
path_LET = f"{reference_output_dir}/members_LET_dict.pickle"
path_seeds = f"{reference_output_dir}/random_seeds.npy"
path_loc = f"{reference_output_dir}/members_seed_loc_dict.pickle"

with open(path_LET,'rb') as handle:
    mems_dict = pickle.load(handle)
    
random_seeds = np.load(path_seeds)    
    
with open(path_loc,'rb') as handle:
    seed_loc_dict = pickle.load(handle)

# %%
# Load Best Parameters from optimization from previous pCO2-Residual Run
# These parameters were held constant for all sampling experiments so that we could strictly 
# assess the impact of the difference in sampling

path_bp="/data/artemis/workspace/vbennington/full_sst/pCO2_DIC/models/performance_metrics/xg/xg_best_params_dict.pickle"
with open(path_bp,'rb') as handle:
    best_params = pickle.load(handle)
print(best_params)
# Out:
# {'CESM': {'max_depth': 6, 'n_estimators': 4000}, 'GFDL': {'max_depth': 6, 'n_estimators': 4000}, 'MPI': {'max_depth': 6, 'n_estimators': 4000}, 'CanESM2': {'max_depth': 6, 'n_estimators': 4000}}

# %%
# Defining inputs for the modeling process

# Train-validate-test split proportions
val_prop = .2
test_prop = .2

# Parameter grids
xg_param_grid = {"n_estimators":[2000, 3000, 4000],
                 "max_depth":[4, 5, 6]
                }
# Feature and target lists for feeding into the models
features_sel = ['sst','sst_anom','sss','sss_anom','mld_clim_log','chl_log','chl_log_anom','xco2','A', 'B', 'C', 'T0', 'T1'] 

# What we reconstruct: pCO2-Residual = pCO2 - pCO2_T
target_sel = ['pCO2_pCO2T_diff']

# %%
# We want to train with 4 out of every 5 months, and test on the fifth month
# so that we don't train and test in the same month

date_range_start = '1979-01-01T00:00:00.000000000'
date_range_end = '2017-01-01T00:00:00.000000000'

# Create date vector
dates = pd.date_range(start=date_range_start, 
                      end=date_range_end,freq='MS') + np.timedelta64(14, 'D')
select_dates = []
test_dates = []
for i in range(0,len(dates)):
    if i % 5 != 0:
        select_dates.append(dates[i])
    if i % 5 == 0:
        test_dates.append(dates[i])
year_mon = []
for i in range(0,len(select_dates)):
    tmp = select_dates[i]
    year_mon.append(f"{tmp.year}-{tmp.month}")
test_year_mon = []
for i in range(0,len(test_dates)):
    tmp = test_dates[i]
    test_year_mon.append(f"{tmp.year}-{tmp.month}")

# %%
# Make dictionary to "store" performance metrics for the reconstruction
# "Unseen" = every 1x1 grid cell that is not in the train or test set. We have unseen output
# since we are using a model testbed and not real-world observations. 
test_performance = defaultdict(dict)
unseen_performance = defaultdict(dict)

# %%
K_folds = 3
approach = "xg"
first_mem = False # Initialize if using gridsearch to find best_params (optimization)

print(datetime.datetime.now())
for ens, mem_list in mems_dict.items():
    
    for member in mem_list:
        print(ens)
        print(member)
        seed_loc = seed_loc_dict[ens][member] 
              
        # Data file path
        data_dir = f"{data_output_dir}/{ens}/member_{member}"
        fname = f"data_clean_2D_mon_{ens}_{member}_1x1_198201-201701.pkl"
        file_path = f"{data_dir}/{fname}"
        
        # Read in data, create some selection filters, produce a reduced dataframe
        df = pd.read_pickle(file_path)
    
        df['year'] = df.index.get_level_values('time').year
        df['mon'] = df.index.get_level_values('time').month
        df['year_month'] = df['year'].astype(str) + "-" + df['mon'].astype(str)
    
        # For pCO2-Residual:
        # Apply mask (remove coast, shallow seas, Arctic etc.) and remove pCO2 values between -250 and +250 ppm
        recon_sel = (~df[features_sel+target_sel+['net_mask']].isna().any(axis=1)) & ((df[target_sel] < 250) & (df[target_sel] > -250)).to_numpy().ravel()
        
        # Select 1x1 grid cells that are not masked as above, and that represents SOCAT and USV sampling
        sel = (recon_sel & ((df['socat_mask'] == 1) | (df['sail_mask']==1)))  
        
        # Select training set
        # Need to train where there is SOCAT/USV data and during a non-test year
        train_sel = (sel & (pd.Series(df['year_month']).isin(year_mon))).to_numpy().ravel()
        print(sum(train_sel))
    
        # Select test set, not during a training month
        test_sel = (sel & (pd.Series(df['year_month']).isin(test_year_mon))).to_numpy().ravel()
        print(sum(test_sel))
        
        # Select "unseen" data - all 1x1 grid cells that are NOT in the train or test set
        unseen_sel = (recon_sel & (df['socat_mask'] == 0) & (np.isnan(df['sail_mask'])))  
        
        ################################################################################################################################
        
        # Convert dataframe to numpy arrays, train/val/test split
        X = df.loc[sel,features_sel].to_numpy()         
        y = df.loc[sel,target_sel].to_numpy().ravel()
        
        # Convert dataframe to numpy arrays, train/val/test split
        Xtrain = df.loc[train_sel,features_sel].to_numpy() # create Xtrain and Xtest to randomly select from for X_train and X_test
        ytrain = df.loc[train_sel,target_sel].to_numpy().ravel()
        
        N = Xtrain.shape[0]
        train_val_idx, train_idx, val_idx, test_idx = pre_saildrone_5.train_val_test_split(N, test_prop, val_prop, random_seeds, seed_loc)
        X_train_val, X_train, X_val, X_test_tmp, y_train_val, y_train, y_val, y_test_tmp = pre_saildrone_5.apply_splits(Xtrain, ytrain, train_val_idx, train_idx, val_idx, test_idx) 
        
        # We don't use X_test_tmp or y_test_tmp when test years are used (X_test and y_test set above)
        X_test = df.loc[test_sel,features_sel].to_numpy() #  Test metrics on all of SOCAT data from test years
        y_test = df.loc[test_sel,target_sel].to_numpy().ravel()    
        
        # Define the model based on which approach to use    
        if first_mem:
            model = XGBRegressor(random_state=random_seeds[4,seed_loc], n_jobs=jobs)
            param_grid = xg_param_grid
            grid = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=K_folds, return_train_score=False, refit=False)
            grid.fit(X_train_val, y_train_val)
            best_params[ens] = grid.best_params_
            print(best_params)
            first_mem = False

        # Fit the model on train/validation data
        model = XGBRegressor(random_state=random_seeds[5,seed_loc], **best_params[ens], n_jobs=jobs)
        model.fit(X_train_val, y_train_val)          

        # Save the model
        pre_saildrone_5.save_model(model, model_output_dir, approach, ens, member)   

        # Calculate some test error metrics and store in a dictionary
        y_pred_test = model.predict(X_test)
        test_performance[ens][member] = pre_saildrone_5.evaluate_test(y_test, y_pred_test)
        print(test_performance[ens][member])
        
        # Redo this analysis on the unseen data
        y_pred_unseen = model.predict(df.loc[unseen_sel,features_sel].to_numpy())
        y_unseen = df.loc[unseen_sel,target_sel].to_numpy().ravel()
        unseen_performance[ens][member] = pre_saildrone_5.evaluate_test(y_unseen, y_pred_unseen)
        print(unseen_performance[ens][member])

        # Create the reconstruction and save it
        # "seen": All SOCAT and USV locations for all training years (not test years)
        y_pred_seen = model.predict(X)
        
        # Full reconstruction (all 1x1 degree grid cells)
        df['pCO2_DIC_recon'] = np.nan
        df.loc[unseen_sel,['pCO2_DIC_recon']] = y_pred_unseen 
        df.loc[sel,['pCO2_DIC_recon']] = y_pred_seen
        
        # All time/locations not sampled by SOCAT and USV ("unseen")
        df['pCO2_DIC_nosocat'] = np.nan
        df.loc[unseen_sel,['pCO2_DIC_nosocat']] = y_pred_unseen
        df.loc[sel,['pCO2_DIC_nosocat']] = np.nan
        
        # Only at time/locations of SOCAT and USV sampling ("training data")
        df['pCO2_DIC_socat'] = np.nan
        df.loc[unseen_sel,['pCO2_DIC_socat']] = np.nan
        df.loc[sel,['pCO2_DIC_socat']] = y_pred_seen
     
        df['pCO2_DIC'] = df['pCO2_pCO2T_diff']
        
        #pCO2_DIC = pCO2-Residual
        #pCO2_DIC_recon = FULL reconstruction
        #pCO2_DIC_socat = training data (also including USV locations)
        #pCO2_DIC_nosocat = UNSEEN reconstruction
        DS_recon = df[['net_mask','socat_mask','pCO2_DIC','pCO2_DIC_recon','pCO2_DIC_socat','pCO2_DIC_nosocat']].to_xarray()
             
        pre_saildrone_5.save_recon(DS_recon, recon_output_dir, approach, ens, member)   

print(datetime.datetime.now())
# Out:
# 2023-06-30 19:02:52.699438
# CESM
# 001
# 177639
# 45033
# Starting model saving process
# Save complete
# {'mse': 88.33086685504661, 'mae': 6.159909766592733, 'medae': 3.9592211836831552, 'max_error': 97.15528431165683, 'bias': -0.22553165178748635, 'r2': 0.9512782320298087, 'corr': 0.9754268027070927, 'cent_rmse': 9.395743836298076, 'stdev': 42.05612, 'amp_ratio': 1.0178044410397251, 'stdev_ref': 42.5789283484277, 'range_ref': 343.5693412871827, 'iqr_ref': 46.63227972178635}
# {'mse': 134.1131069968853, 'mae': 8.049936902802674, 'medae': 5.601249506117597, 'max_error': 184.16786199062136, 'bias': 0.9618432393208447, 'r2': 0.8985544166176842, 'corr': 0.9494753346473421, 'cent_rmse': 11.540708896181423, 'stdev': 36.246918, 'amp_ratio': 0.9019974552305252, 'stdev_ref': 36.359595241645955, 'range_ref': 497.3343291769688, 'iqr_ref': 43.051529530222226}
# Starting reconstruction saving process
# Save complete
# CESM
# 002
# Starting model saving process
# Save complete
# {'mse': 84.13740066987086, 'mae': 5.999423194930996, 'medae': 3.8682400522276907, 'max_error': 84.37811783948578, 'bias': -0.10901295946252187, 'r2': 0.9549759163999152, 'corr': 0.9772349279604516, 'cent_rmse': 9.171996327148396, 'stdev': 42.14022, 'amp_ratio': 0.9032111684400219, 'stdev_ref': 43.22869293197307, 'range_ref': 350.3211790564294, 'iqr_ref': 46.54700015682414}
# {'mse': 124.63563670342934, 'mae': 7.779375637789656, 'medae': 5.418188471050712, 'max_error': 161.50134587247652, 'bias': 0.5354494445701377, 'r2': 0.9016079105304109, 'corr': 0.9502799479242225, 'cent_rmse': 11.151185168492097, 'stdev': 35.053204, 'amp_ratio': 0.8429251472836662, 'stdev_ref': 35.59106851675969, 'range_ref': 472.42270712141703, 'iqr_ref': 41.59493275833445}
# Starting reconstruction saving process
# Save complete
# CESM
# 009
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 86.51471560250049, 'mae': 5.952465839516466, 'medae': 3.815273153764906, 'max_error': 98.1422316723802, 'bias': 0.024760144398633277, 'r2': 0.9524469389822648, 'corr': 0.975946503998469, 'cent_rmse': 9.301295781350872, 'stdev': 41.417366, 'amp_ratio': 0.9162344841108693, 'stdev_ref': 42.65360602893783, 'range_ref': 334.72965954911876, 'iqr_ref': 46.33200532061164}
# {'mse': 122.22893943374494, 'mae': 7.662244803942524, 'medae': 5.36772658292864, 'max_error': 225.82260272598683, 'bias': 0.46071730480214046, 'r2': 0.9029392992024552, 'corr': 0.9507800188994582, 'cent_rmse': 11.046115506327048, 'stdev': 34.789604, 'amp_ratio': 0.8689241528016644, 'stdev_ref': 35.48667510487759, 'range_ref': 467.7809037505934, 'iqr_ref': 41.35493995041875}
# Starting reconstruction saving process
# Save complete
# CESM
# 010
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 84.79530579722474, 'mae': 5.992683629034128, 'medae': 3.8965783394949653, 'max_error': 90.46077691883903, 'bias': 0.042086717101062376, 'r2': 0.9557584457414523, 'corr': 0.9776823961892407, 'cent_rmse': 9.20834039026705, 'stdev': 43.247826, 'amp_ratio': 0.8357582176090216, 'stdev_ref': 43.77949195509462, 'range_ref': 426.46850851978695, 'iqr_ref': 46.98624127854828}
# {'mse': 125.52374801397191, 'mae': 7.810153552892032, 'medae': 5.496821237855954, 'max_error': 193.01356735107504, 'bias': 0.9211724806266295, 'r2': 0.9026745785544923, 'corr': 0.9509933689446501, 'cent_rmse': 11.165804182394458, 'stdev': 35.319847, 'amp_ratio': 0.8898386046728956, 'stdev_ref': 35.912844303181195, 'range_ref': 480.7357760731413, 'iqr_ref': 41.97520510069148}
# Starting reconstruction saving process
# Save complete
# CESM
# 011
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse':
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 90.16066812823787, 'mae': 6.117609592348374, 'medae': 3.967531554969355, 'max_error': 96.56138885605145, 'bias': 0.036631731813985935, 'r2': 0.9521597888644147, 'corr': 0.9757877115204389, 'cent_rmse': 9.495226500072327, 'stdev': 42.314415, 'amp_ratio': 0.980381104838781, 'stdev_ref': 43.41222216125447, 'range_ref': 315.4530928662088, 'iqr_ref': 46.58679997557482}
# {'mse': 126.78160440011568, 'mae': 7.835169075812298, 'medae': 5.526911099387519, 'max_error': 191.31189860726045, 'bias': 0.5059863830554006, 'r2': 0.903742430520593, 'corr': 0.9512576197320601, 'cent_rmse': 11.248358980093293, 'stdev': 35.644127, 'amp_ratio': 0.8507524890641168, 'stdev_ref': 36.29198109404356, 'range_ref': 485.9148281381795, 'iqr_ref': 42.4138246017944}
# Starting reconstruction saving process
# Save complete
# CESM
# 025
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 79.63148662081902, 'mae': 5.9593404082891, 'medae': 4.020867721958382, 'max_error': 85.59851498958801, 'bias': 0.0956719196238991, 'r2': 0.9562633112585313, 'corr': 0.9779003645129585, 'cent_rmse': 8.923134662256093, 'stdev': 41.921234, 'amp_ratio': 0.9932587125580523, 'stdev_ref': 42.66968745645475, 'range_ref': 352.9039598943777, 'iqr_ref': 47.10564242402876}
# {'mse': 122.20972207661846, 'mae': 7.777032338068062, 'medae': 5.517340656998158, 'max_error': 165.4812225655374, 'bias': 1.563080235960891, 'r2': 0.905478179480777, 'corr': 0.9527045530542222, 'cent_rmse': 10.94378683982524, 'stdev': 34.856274, 'amp_ratio': 0.8947490131975445, 'stdev_ref': 35.95728061463231, 'range_ref': 480.7802713327701, 'iqr_ref': 41.979297948308385}
# Starting reconstruction saving process
# Save complete
# CESM
# 030
# 177637
# 45033
# Starting model saving process
# Save complete
# {'mse': 81.65876488470343, 'mae': 5.998999254736163, 'medae': 3.9535140795015877, 'max_error': 80.73208222416736, 'bias': 0.1628745641108127, 'r2': 0.9547964136016055, 'corr': 0.9771736549050316, 'cent_rmse': 9.03505599437361, 'stdev': 41.85397, 'amp_ratio': 1.043161245150971, 'stdev_ref': 42.50254708039509, 'range_ref': 307.6850778513438, 'iqr_ref': 46.94268771502601}
# {'mse': 129.17538139669455, 'mae': 7.917082527408863, 'medae': 5.534887995162308, 'max_error': 177.66609784032727, 'bias': 1.0457219092470869, 'r2': 0.901414795387722, 'corr': 0.9504605286818674, 'cent_rmse': 11.31732484568057, 'stdev': 35.61929, 'amp_ratio': 0.971062462850177, 'stdev_ref': 36.19795244723858, 'range_ref': 484.4923040873948, 'iqr_ref': 42.74095372992895}
# Starting reconstruction saving process
# Save complete
# CESM
# 031
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 93.10482221056321, 'mae': 6.14344400658094, 'medae': 3.9197116013742175, 'max_error': 110.0298510853136, 'bias': 0.5445537432660188, 'r2': 0.9516341380723669, 'corr': 0.9757583798499219, 'cent_rmse': 9.633705583830933, 'stdev': 42.031124, 'amp_ratio': 1.0515971877454722, 'stdev_ref': 43.87494870134407, 'range_ref': 298.5781546516485, 'iqr_ref': 47.7503472804363}
# {'mse': 125.83237278691851, 'mae': 7.822208812578605, 'medae': 5.487418187357946, 'max_error': 181.68629288920857, 'bias': 0.8236395122268114, 'r2': 0.9039878155608254, 'corr': 0.9516122539055152, 'cent_rmse': 11.187224806383913, 'stdev': 35.62921, 'amp_ratio': 0.9599757029219348, 'stdev_ref': 36.20203781279855, 'range_ref': 474.96541823157685, 'iqr_ref': 42.34794944407383}
# Starting reconstruction saving process
# Save complete
# CESM
# 034
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 93.95546488085695, 'mae': 6.2576017530805, 'medae': 3.9988578993902593, 'max_error': 107.8089971629604, 'bias': -0.16352043984183862, 'r2': 0.9503964822351867, 'corr': 0.9749025372999917, 'cent_rmse': 9.691683367485377, 'stdev': 42.64411, 'amp_ratio': 0.9017181922478856, 'stdev_ref': 43.521593125144086, 'range_ref': 387.60664462067643, 'iqr_ref': 47.36452901045004}
# {'mse': 134.4914906459944, 'mae': 8.073748973798526, 'medae': 5.636862216843497, 'max_error': 230.33039275010714, 'bias': 0.9275296858674054, 'r2': 0.8967783076192658, 'corr': 0.9482835616717443, 'cent_rmse': 11.559895610579769, 'stdev': 35.762238, 'amp_ratio': 0.8224762697948783, 'stdev_ref': 36.09623587463253, 'range_ref': 497.6659332824743, 'iqr_ref': 42.1714971066001}
# Starting reconstruction saving process
# Save complete
# CESM
# 035
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 80.54039369105875, 'mae': 5.923135280447204, 'medae': 3.834009136961754, 'max_error': 77.2427461050267, 'bias': -0.36780646013090723, 'r2': 0.9573041384961436, 'corr': 0.9786247758977576, 'cent_rmse': 8.96688974910206, 'stdev': 43.293743, 'amp_ratio': 0.9371141078067634, 'stdev_ref': 43.432415517611474, 'range_ref': 358.764405779795, 'iqr_ref': 47.89553806395037}
# {'mse': 127.07830583788585, 'mae': 7.837570238096278, 'medae': 5.4648911500258635, 'max_error': 247.27072125380414, 'bias': 0.7456213283391073, 'r2': 0.902184574701703, 'corr': 0.9505999215944336, 'cent_rmse': 11.248215617429846, 'stdev': 35.41884, 'amp_ratio': 0.9479723971630377, 'stdev_ref': 36.043921434930404, 'range_ref': 473.64074459813617, 'iqr_ref': 42.13239132165609}
# Starting reconstruction saving process
# Save complete
# CESM
# 101
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 89.60012840867958, 'mae': 6.2220377786296845, 'medae': 4.03278243515291, 'max_error': 82.6377285439712, 'bias': -0.34920571035729997, 'r2': 0.9514990788175268, 'corr': 0.9754902851927353, 'cent_rmse': 9.459290921284131, 'stdev': 42.10086, 'amp_ratio': 0.8922854699731834, 'stdev_ref': 42.981277781078376, 'range_ref': 352.30998885796356, 'iqr_ref': 47.00033804498389}
# {'mse': 128.06871283850037, 'mae': 7.874377494837477, 'medae': 5.5411198777848085, 'max_error': 213.35064030629826, 'bias': 0.22583185169444753, 'r2': 0.9017061717872811, 'corr': 0.9499652371649121, 'cent_rmse': 11.314491283162244, 'stdev': 35.237095, 'amp_ratio': 0.943434196615813, 'stdev_ref': 36.0959434413136, 'range_ref': 499.2249619193123, 'iqr_ref': 41.899182383104545}
# Starting reconstruction saving process
# Save complete
# CESM
# 102
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 81.76592593894043, 'mae': 5.943297221388302, 'medae': 3.9153721952527007, 'max_error': 89.23433010506807, 'bias': 0.07573912261935178, 'r2': 0.9558683174287045, 'corr': 0.9777041091480696, 'cent_rmse': 9.042134138679515, 'stdev': 42.33479, 'amp_ratio': 0.9747408740809183, 'stdev_ref': 43.0438328961309, 'range_ref': 318.4725611808906, 'iqr_ref': 47.07654423622057}
# {'mse': 122.04151411958986, 'mae': 7.722373952816943, 'medae': 5.457110396022955, 'max_error': 228.23749046003167, 'bias': 0.660936814708003, 'r2': 0.906108613650678, 'corr': 0.9523432167447642, 'cent_rmse': 11.02745095898014, 'stdev': 35.15129, 'amp_ratio': 0.8946604945619369, 'stdev_ref': 36.052959253307286, 'range_ref': 484.78141747748526, 'iqr_ref': 42.13411038295625}
# Starting reconstruction saving process
# Save complete
# CESM
# 103
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 83.16589078655797, 'mae': 5.994108979297995, 'medae': 3.848658080883638, 'max_error': 90.46682365654749, 'bias': -0.4276308414695298, 'r2': 0.9540667643855705, 'corr': 0.9768410845719393, 'cent_rmse': 9.109501794278634, 'stdev': 41.8686, 'amp_ratio': 1.0684426933723714, 'stdev_ref': 42.55093448701265, 'range_ref': 316.49217094766647, 'iqr_ref': 45.990734601572626}
# {'mse': 125.43706907216948, 'mae': 7.738593395969357, 'medae': 5.359047047800459, 'max_error': 193.18938332701651, 'bias': 0.12127863256667504, 'r2': 0.9014800360713955, 'corr': 0.950212768243051, 'cent_rmse': 11.199212462487216, 'stdev': 35.246773, 'amp_ratio': 0.8997013803191233, 'stdev_ref': 35.68213457686983, 'range_ref': 464.0767099800059, 'iqr_ref': 41.86384982021312}
# Starting reconstruction saving process
# Save complete
# CESM
# 104
# 177641
# 45033
# Starting model saving process
# Save complete
# {'mse': 81.10948704954424, 'mae': 5.967036493376689, 'medae': 3.9121760517129474, 'max_error': 79.43983331787877, 'bias': 0.02251833508035128, 'r2': 0.9567843152383102, 'corr': 0.978153749492359, 'cent_rmse': 9.006052446729854, 'stdev': 42.394203, 'amp_ratio': 0.9477394812392799, 'stdev_ref': 43.32266136154353, 'range_ref': 387.5482092286063, 'iqr_ref': 47.83822951172965}
# {'mse': 127.6522563424917, 'mae': 7.847125420338099, 'medae': 5.489054780690594, 'max_error': 216.04756427236896, 'bias': 0.7557544172027064, 'r2': 0.9015118238024443, 'corr': 0.950011710444312, 'cent_rmse': 11.27302486143318, 'stdev': 35.06133, 'amp_ratio': 0.9832467272955037, 'stdev_ref': 36.001632983362775, 'range_ref': 481.26553148124214, 'iqr_ref': 42.41165534047013}
# Starting reconstruction saving process
# Save complete
# GFDL
# 01
# 178644
# 45873
# Starting model saving process
# Save complete
# {'mse': 61.54663025374768, 'mae': 5.7212605807693215, 'medae': 4.254636392043892, 'max_error': 74.9959542394119, 'bias': -0.009537610294682697, 'r2': 0.9552956615661417, 'corr': 0.9773923335077133, 'cent_rmse': 7.8451602550480555, 'stdev': 36.25776, 'amp_ratio': 1.0210765788124576, 'stdev_ref': 37.104561524691775, 'range_ref': 317.9115124638861, 'iqr_ref': 40.44039152918498}
# 178647
# 45873
# Starting model saving process
# Save complete
# {'mse': 62.273748665267156, 'mae': 5.710869530763969, 'medae': 4.270508369310335, 'max_error': 76.82710829469852, 'bias': -0.039651355262455334, 'r2': 0.9565224628427044, 'corr': 0.9780209371521592, 'cent_rmse': 7.891272196079607, 'stdev': 37.058853, 'amp_ratio': 1.0371824784746833, 'stdev_ref': 37.846004555514035, 'range_ref': 347.69515395550104, 'iqr_ref': 41.20912067780472}
# {'mse': 116.51373698820635, 'mae': 7.811306671666769, 'medae': 5.792747078295747, 'max_error': 191.6474152013633, 'bias': 0.679436322568356, 'r2': 0.9016837590080737, 'corr': 0.9499714066009156, 'cent_rmse': 10.772748643596794, 'stdev': 33.367226, 'amp_ratio': 0.9225129528543501, 'stdev_ref': 34.425157283483465, 'range_ref': 497.1970462993032, 'iqr_ref': 41.503041314902816}
# Starting reconstruction saving process
# Save complete
# GFDL
# 19
# 178646
# 45871
# Starting model saving process
# Save complete
# {'mse': 68.93382392780197, 'mae': 5.965285247089632, 'medae': 4.414809641733655, 'max_error': 106.47000437156856, 'bias': -0.02216845278257007, 'r2': 0.9520840725886488, 'corr': 0.9757718821515319, 'cent_rmse': 8.302609960133564, 'stdev': 37.268696, 'amp_ratio': 0.8282326452293631, 'stdev_ref': 37.92942300391833, 'range_ref': 422.96716759750524, 'iqr_ref': 42.766973303866564}
# {'mse': 127.16464027003856, 'mae': 8.13607482980348, 'medae': 6.0291429730486925, 'max_error': 169.6755449896794, 'bias': 0.9804270244899993, 'r2': 0.8958322251141592, 'corr': 0.9473250402372688, 'cent_rmse': 11.234029457680146, 'stdev': 34.090458, 'amp_ratio': 0.9662949429272373, 'stdev_ref': 34.93948424008883, 'range_ref': 499.59447554588604, 'iqr_ref': 41.745207023303905}
# Starting reconstruction saving process
# Save complete
# GFDL
# 20
# 178647
# 45873
# Starting model saving process
# Save complete
# {'mse': 63.13609817994722, 'mae': 5.677080132264138, 'medae': 4.131682825120606, 'max_error': 67.6427289131563, 'bias': 0.12229567372501049, 'r2': 0.9525716890364838, 'corr': 0.9760322569816473, 'cent_rmse': 7.944881499189221, 'stdev': 35.88414, 'amp_ratio': 0.970379001993209, 'stdev_ref': 36.48547798085475, 'range_ref': 329.7900105136146, 'iqr_ref': 40.59300679880039}
# {'mse': 123.25547012170942, 'mae': 7.94072468381906, 'medae': 5.85556888024044, 'max_error': 225.70938516565673, 'bias': 0.9983933793285498, 'r2': 0.8952745873704566, 'corr': 0.9471471740568435, 'cent_rmse': 11.057065345237243, 'stdev': 33.559757, 'amp_ratio': 0.8487138961581856, 'stdev_ref': 34.306551204439, 'range_ref': 493.48816264981485, 'iqr_ref': 41.31877388856779}
# Starting reconstruction saving process
# Save complete
# GFDL
# 22
# 178647
# 45873
# Starting model saving process
# Save complete
# {'mse': 65.83917796737911, 'mae': 5.907528460441302, 'medae': 4.385370723614415, 'max_error': 62.31179881826978, 'bias': 0.3297375951892303, 'r2': 0.953005003297781, 'corr': 0.9762927035936038, 'cent_rmse': 8.107431844047115, 'stdev': 36.843723, 'amp_ratio': 0.9449769668199335, 'stdev_ref': 37.42970361609718, 'range_ref': 360.3704863072307, 'iqr_ref': 43.33963897342272}
# {'mse': 120.58123061385572, 'mae': 7.938594649073202, 'medae': 5.87186648919635, 'max_error': 178.10058057911687, 'bias': 1.0855025702046455, 'r2': 0.8978519424196982, 'corr': 0.9487736603629232, 'cent_rmse': 10.927163637087109, 'stdev': 33.846645, 'amp_ratio': 0.9186248677303193, 'stdev_ref': 34.35775667156283, 'range_ref': 496.98035533436024, 'iqr_ref': 41.224275531969}
# Starting reconstruction saving process
# Save complete
# GFDL
# 23
# 178646
# 45873
# Starting model saving process
# Save complete
# {'mse': 64.64649994827131, 'mae': 5.768845657254867, 'medae': 4.284084301532573, 'max_error': 72.31510198793956, 'bias': 0.17195693452820726, 'r2': 0.9543242282660207, 'corr': 0.9769083540303753, 'cent_rmse': 8.03846569628335, 'stdev': 36.83473, 'amp_ratio': 0.9347572561063442, 'stdev_ref': 37.620932953746156, 'range_ref': 320.6359671637598, 'iqr_ref': 42.13035796511275}
# {'mse': 116.39068451633642, 'mae': 7.743616506843182, 'medae': 5.720324269924731, 'max_error': 200.6176703861126, 'bias': 0.9484343248734688, 'r2': 0.9013603769153735, 'corr': 0.9500344218957754, 'cent_rmse': 10.746680428801032, 'stdev': 33.356926, 'amp_ratio': 0.8641399725654184, 'stdev_ref': 34.35052738104118, 'range_ref': 499.1181597587859, 'iqr_ref': 41.237455712131535}
# Starting reconstruction saving process
# Save complete
# GFDL
# 26
# 178647
# 45873
# Starting model saving process
# Save complete
# {'mse': 66.8335732002494, 'mae': 5.873195355760149, 'medae': 4.339306519662841, 'max_error': 72.20287390353855, 'bias': 0.4857671266916699, 'r2': 0.9530257780726189, 'corr': 0.976328185291534, 'cent_rmse': 8.160735471257924, 'stdev': 36.63779, 'amp_ratio': 0.8687603190926771, 'stdev_ref': 37.71964032151341, 'range_ref': 381.406567301946, 'iqr_ref': 41.20730905798035}
# {'mse': 121.67681392628474, 'mae': 7.9524708074579475, 'medae': 5.903920095480146, 'max_error': 191.458481928227, 'bias': 0.6496487871360155, 'r2': 0.8990139194337525, 'corr': 0.948828908606313, 'cent_rmse': 11.01157451843791, 'stdev': 33.98359, 'amp_ratio': 0.8909893650225242, 'stdev_ref': 34.71148200350177, 'range_ref': 497.53093211825586, 'iqr_ref': 41.23358423778214}
# Starting reconstruction saving process
# Save complete
# GFDL
# 27
# 178647
# 45873
# Starting model saving process
# Save complete
# {'mse': 66.15486857993696, 'mae': 5.849433877060618, 'medae': 4.3508099297530975, 'max_error': 83.89695177291037, 'bias': -0.11847306473303454, 'r2': 0.9533151561516326, 'corr': 0.9763846616282998, 'cent_rmse': 8.13270144836116, 'stdev': 36.807304, 'amp_ratio': 0.8963336630827414, 'stdev_ref': 37.64375604500597, 'range_ref': 357.48224523812127, 'iqr_ref': 43.363415963711475}
# {'mse': 121.5090143831421, 'mae': 7.958116248283973, 'medae': 5.905319856052415, 'max_error': 208.94750046097266, 'bias': 0.6403649396227107, 'r2': 0.8979496228582966, 'corr': 0.9478576014846802, 'cent_rmse': 11.004496479737202, 'stdev': 33.115242, 'amp_ratio': 0.8225161147328012, 'stdev_ref': 34.50618465314211, 'range_ref': 496.6479917481054, 'iqr_ref': 41.562486384285364}
# Starting reconstruction saving process
# Save complete
# GFDL
# 28
# 178647
# 45873
# Starting model saving process
# Save complete
# {'mse':

# Starting reconstruction saving process
# Save complete
# CanESM2
# r1r10
# 173225
# 44540
# Starting model saving process
# Save complete
# {'mse': 85.90612, 'mae': 5.8796597, 'medae': 3.9761248, 'max_error': 173.82336, 'bias': 0.42487764, 'r2': 0.8922444641008883, 'corr': 0.9447398135644663, 'cent_rmse': 9.2588117472391, 'stdev': 26.898075, 'amp_ratio': 1.1391624, 'stdev_ref': 28.235292, 'range_ref': 450.35303, 'iqr_ref': 30.887115478515625}
# {'mse': 174.64917, 'mae': 8.159698, 'medae': 5.5615387, 'max_error': 402.38104, 'bias': 0.4916165, 'r2': 0.7770398304253652, 'corr': 0.8826426940100764, 'cent_rmse': 13.206347889180334, 'stdev': 25.860546, 'amp_ratio': 1.3616438, 'stdev_ref': 27.987875, 'range_ref': 499.97675, 'iqr_ref': 32.588287353515625}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r1r9
# 173274
# 44517
# Starting model saving process
# Save complete
# {'mse': 101.717834, 'mae': 6.121483, 'medae': 4.075308, 'max_error': 215.85667, 'bias': -0.040542126, 'r2': 0.8804543365991006, 'corr': 0.9384294630984311, 'cent_rmse': 10.085445430814117, 'stdev': 27.779545, 'amp_ratio': 0.9589354, 'stdev_ref': 29.169682, 'range_ref': 488.51114, 'iqr_ref': 30.93646240234375}
# {'mse': 173.51071, 'mae': 8.253158, 'medae': 5.64538, 'max_error': 410.52386, 'bias': 0.3419845, 'r2': 0.782252975658013, 'corr': 0.8854251993533149, 'cent_rmse': 13.167906701942949, 'stdev': 26.115547, 'amp_ratio': 1.2169601, 'stdev_ref': 28.228456, 'range_ref': 499.93463, 'iqr_ref': 32.49995422363281}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r3r1
# 173167
# 44537
# Starting model saving process
# Save complete
# {'mse': 96.25035, 'mae': 6.1296253, 'medae': 4.1131983, 'max_error': 265.4062, 'bias': 0.31070852, 'r2': 0.8845586760239118, 'corr': 0.9405720390893024, 'cent_rmse': 9.805804643256396, 'stdev': 27.126053, 'amp_ratio': 0.92982095, 'stdev_ref': 28.8749, 'range_ref': 493.28378, 'iqr_ref': 31.4697265625}
# {'mse': 176.3672, 'mae': 8.22301, 'medae': 5.5961018, 'max_error': 394.2043, 'bias': 0.26076984, 'r2': 0.7847408395761956, 'corr': 0.8869552299114348, 'cent_rmse': 13.277769529028223, 'stdev': 26.624462, 'amp_ratio': 1.1737921, 'stdev_ref': 28.623869, 'range_ref': 499.99115, 'iqr_ref': 32.88323974609375}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r4r5
# 173238
# 44527
# Starting model saving process
# Save complete
# {'mse': 93.39174, 'mae': 5.8539867, 'medae': 3.9810028, 'max_error': 228.85585, 'bias': -0.42495012, 'r2': 0.8894857729606457, 'corr': 0.9432478076819218, 'cent_rmse': 9.654592897312975, 'stdev': 27.539948, 'amp_ratio': 0.7843959, 'stdev_ref': 29.07001, 'range_ref': 486.13837, 'iqr_ref': 30.222305297851562}
# {'mse': 169.9911, 'mae': 8.013245, 'medae': 5.4506226, 'max_error': 455.7807, 'bias': -0.09006441, 'r2': 0.7839133578481492, 'corr': 0.88640855224246, 'cent_rmse': 13.037750651221296, 'stdev': 26.05061, 'amp_ratio': 1.2133491, 'stdev_ref': 28.047829, 'range_ref': 499.97134, 'iqr_ref': 32.128936767578125}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r5r10
# 173271
# 44528
# Starting model saving process
# Save complete
# {'mse': 98.77946, 'mae': 5.9396033, 'medae': 3.978981, 'max_error': 236.629, 'bias': -0.38559103, 'r2': 0.880067122061445, 'corr': 0.9382164890864555, 'cent_rmse': 9.93130318126423, 'stdev': 26.880001, 'amp_ratio': 0.73988146, 'stdev_ref': 28.69883, 'range_ref': 489.95334, 'iqr_ref': 29.650558471679688}
# {'mse': 164.68796, 'mae': 7.9845114, 'medae': 5.45643, 'max_error': 388.52307, 'bias': 0.70086044, 'r2': 0.785952007990454, 'corr': 0.8881599035554425, 'cent_rmse': 12.813933745423206, 'stdev': 25.947884, 'amp_ratio': 1.1555431, 'stdev_ref': 27.738012, 'range_ref': 499.97995, 'iqr_ref': 32.496551513671875}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r2r1
# 173230
# 44510
# Starting model saving process
# Save complete
# {'mse': 93.46445, 'mae': 5.9961805, 'medae': 3.964694, 'max_error': 218.5493, 'bias': 0.0038499832, 'r2': 0.8826021798386464, 'corr': 0.9395002827678102, 'cent_rmse': 9.667700022497886, 'stdev': 26.724764, 'amp_ratio': 0.9072256, 'stdev_ref': 28.215853, 'range_ref': 489.02582, 'iqr_ref': 31.008087158203125}
# {'mse': 168.7031, 'mae': 8.074986, 'medae': 5.4903316, 'max_error': 430.4876, 'bias': 0.175426, 'r2': 0.7902905247908787, 'corr': 0.8902340072109255, 'cent_rmse': 12.98739418927395, 'stdev': 26.576395, 'amp_ratio': 1.2093196, 'stdev_ref': 28.363014, 'range_ref': 499.9785, 'iqr_ref': 32.822723388671875}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r3r2
# 173281
# 44497
# Starting model saving process
# Save complete
# {'mse': 103.055, 'mae': 5.9314127, 'medae': 3.9538932, 'max_error': 273.96466, 'bias': 0.030800343, 'r2': 0.8660089487048966, 'corr': 0.9306475886933017, 'cent_rmse': 10.151554552099782, 'stdev': 26.079594, 'amp_ratio': 0.8281555, 'stdev_ref': 27.732986, 'range_ref': 472.82532, 'iqr_ref': 30.170928955078125}
# {'mse': 177.68286, 'mae': 8.055302, 'medae': 5.437731, 'max_error': 355.97137, 'bias': 0.33423126, 'r2': 0.7723220568370706, 'corr': 0.879966144251887, 'cent_rmse': 13.32558772144517, 'stdev': 25.792353, 'amp_ratio': 1.1184512, 'stdev_ref': 27.935888, 'range_ref': 499.98972, 'iqr_ref': 32.98272705078125}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r3r9
# 173238
# 44503
# Starting model saving process
# Save complete
# {'mse': 98.89288, 'mae': 5.964196, 'medae': 3.9629784, 'max_error': 217.15013, 'bias': 0.03160429, 'r2': 0.8790398775886833, 'corr': 0.9375759087689812, 'cent_rmse': 9.944439838082092, 'stdev': 26.886438, 'amp_ratio': 0.9426285, 'stdev_ref': 28.59311, 'range_ref': 435.304, 'iqr_ref': 30.398529052734375}
# {'mse': 171.7536, 'mae': 8.141591, 'medae': 5.5596642, 'max_error': 387.27893, 'bias': 0.4764675, 'r2': 0.7852084495219103, 'corr': 0.8868706490863582, 'cent_rmse': 13.096815315131156, 'stdev': 25.99376, 'amp_ratio': 1.3158317, 'stdev_ref': 28.277733, 'range_ref': 499.9787, 'iqr_ref': 32.68634033203125}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r4r6
# 173149
# 44503
# Starting model saving process
# Save complete
# {'mse': 114.13412, 'mae': 6.2696643, 'medae': 4.1490736, 'max_error': 254.86082, 'bias': -0.31326628, 'r2': 0.8714343361603796, 'corr': 0.9336342555372795, 'cent_rmse': 10.678762807685263, 'stdev': 27.4806, 'amp_ratio': 0.7979265, 'stdev_ref': 29.795128, 'range_ref': 494.43298, 'iqr_ref': 31.12298583984375}
# {'mse': 178.14307, 'mae': 8.191195, 'medae': 5.5462856, 'max_error': 435.96356, 'bias': 0.07784891, 'r2': 0.7832175450089847, 'corr': 0.8857429543542505, 'cent_rmse': 13.346797519514505, 'stdev': 26.430788, 'amp_ratio': 1.2339233, 'stdev_ref': 28.666327, 'range_ref': 499.96487, 'iqr_ref': 32.91021728515625}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r5r2
# 173264
# 44542
# Starting model saving process
# Save complete
# {'mse': 98.386734, 'mae': 6.100206, 'medae': 4.0744114, 'max_error': 238.70676, 'bias': 0.0057258606, 'r2': 0.8773999862117907, 'corr': 0.9367366022421929, 'cent_rmse': 9.919007129655078, 'stdev': 26.78235, 'amp_ratio': 0.7301083, 'stdev_ref': 28.328463, 'range_ref': 494.9637, 'iqr_ref': 31.399124145507812}
# {'mse': 172.11548, 'mae': 8.121845, 'medae': 5.532342, 'max_error': 376.1395, 'bias': -0.18399239, 'r2': 0.7798062444165597, 'corr': 0.8844735002171572, 'cent_rmse': 13.117996101960058, 'stdev': 26.110312, 'amp_ratio': 1.0417353, 'stdev_ref': 27.958113, 'range_ref': 499.976, 'iqr_ref': 32.324378967285156}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r1r6
# 173253
# 44497
# Starting model saving process
# Save complete
# {'mse': 117.289185, 'mae': 6.1253977, 'medae': 4.0665975, 'max_error': 255.37451, 'bias': -0.19927979, 'r2': 0.865604227564764, 'corr': 0.930405841833947, 'cent_rmse': 10.82817926782486, 'stdev': 27.553818, 'amp_ratio': 0.90204954, 'stdev_ref': 29.541746, 'range_ref': 447.69144, 'iqr_ref': 30.871002197265625}
# {'mse': 178.35892, 'mae': 8.1166525, 'medae': 5.489911, 'max_error': 460.70963, 'bias': 0.2143699, 'r2': 0.7770285502752867, 'corr': 0.8818997413725241, 'cent_rmse': 13.353379167239646, 'stdev': 25.66984, 'amp_ratio': 1.1378239, 'stdev_ref': 28.282808, 'range_ref': 499.9791, 'iqr_ref': 32.351951599121094}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r2r2
# 173245
# 44524
# Starting model saving process
# Save complete
# {'mse': 101.484085, 'mae': 5.969592, 'medae': 3.9446287, 'max_error': 314.58978, 'bias': 0.12143469, 'r2': 0.8793565045893392, 'corr': 0.9379612755457933, 'cent_rmse': 10.07319921262083, 'stdev': 27.782066, 'amp_ratio': 0.86668336, 'stdev_ref': 29.003273, 'range_ref': 498.80646, 'iqr_ref': 30.759132385253906}
# {'mse': 169.99373, 'mae': 7.998364, 'medae': 5.432535, 'max_error': 384.2174, 'bias': 0.19073617, 'r2': 0.7826753870759262, 'corr': 0.8863361925148432, 'cent_rmse': 13.036770882176612, 'stdev': 26.287373, 'amp_ratio': 1.2011887, 'stdev_ref': 27.968029, 'range_ref': 499.95206, 'iqr_ref': 32.594940185546875}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r3r4
# 173230
# 44525
# Starting model saving process
# Save complete
# {'mse': 88.172844, 'mae': 5.962991, 'medae': 4.0813828, 'max_error': 194.17804, 'bias': 0.15419102, 'r2': 0.893653750255479, 'corr': 0.945389468882435, 'cent_rmse': 9.388773505594855, 'stdev': 27.477457, 'amp_ratio': 0.87258285, 'stdev_ref': 28.794289, 'range_ref': 466.76428, 'iqr_ref': 30.6796875}
# {'mse': 176.10277, 'mae': 8.292536, 'medae': 5.6488495, 'max_error': 373.9544, 'bias': 0.06318152, 'r2': 0.7792471998311076, 'corr': 0.8842430509415335, 'cent_rmse': 13.27022651946582, 'stdev': 26.42423, 'amp_ratio': 1.2006671, 'stdev_ref': 28.244274, 'range_ref': 499.9809, 'iqr_ref': 32.380462646484375}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r4r1
# 173214
# 44490
# Starting model saving process
# Save complete
# {'mse': 101.799034, 'mae': 6.0568395, 'medae': 4.037363, 'max_error': 263.77682, 'bias': 0.032645702, 'r2': 0.8793321691825968, 'corr': 0.9378748888213353, 'cent_rmse': 10.08949779895011, 'stdev': 27.723297, 'amp_ratio': 0.857352, 'stdev_ref': 29.045315, 'range_ref': 499.00043, 'iqr_ref': 31.33135986328125}
# {'mse': 180.18584, 'mae': 8.369796, 'medae': 5.6932526, 'max_error': 385.77148, 'bias': 0.47021222, 'r2': 0.7783245686768698, 'corr': 0.883462873045216, 'cent_rmse': 13.41509161537353, 'stdev': 26.433784, 'amp_ratio': 1.1420269, 'stdev_ref': 28.510279, 'range_ref': 499.98727, 'iqr_ref': 33.40489959716797}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r4r7
# 173264
# 44539
# Starting model saving process
# Save complete
# {'mse': 92.38706, 'mae': 5.8891506, 'medae': 4.0075293, 'max_error': 289.45355, 'bias': 0.0530262, 'r2': 0.8780820624546941, 'corr': 0.9371662554199903, 'cent_rmse': 9.61167304580902, 'stdev': 26.182367, 'amp_ratio': 0.9064732, 'stdev_ref': 27.527819, 'range_ref': 445.2691, 'iqr_ref': 30.478485107421875}
# {'mse': 170.09781, 'mae': 7.9934893, 'medae': 5.440425, 'max_error': 398.4756, 'bias': -0.010234833, 'r2': 0.7826804534878061, 'corr': 0.885249227111882, 'cent_rmse': 13.042142458105307, 'stdev': 25.644861, 'amp_ratio': 1.0507762, 'stdev_ref': 27.976902, 'range_ref': 499.97638, 'iqr_ref': 32.9464111328125}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r5r4
# 173264
# 44525
# Starting model saving process
# 173261
# 44533
# Starting model saving process
# Save complete
# {'mse': 99.13533, 'mae': 6.0619507, 'medae': 4.0653105, 'max_error': 224.91791, 'bias': -0.35502577, 'r2': 0.8756973887363597, 'corr': 0.9360229256094805, 'cent_rmse': 9.950340961451577, 'stdev': 26.90935, 'amp_ratio': 1.0037205, 'stdev_ref': 28.240612, 'range_ref': 451.56512, 'iqr_ref': 30.410369873046875}
# {'mse': 177.14882, 'mae': 8.181873, 'medae': 5.573572, 'max_error': 419.2608, 'bias': 0.385162, 'r2': 0.7783044176595113, 'corr': 0.8835359513249045, 'cent_rmse': 13.304155661103204, 'stdev': 26.284958, 'amp_ratio': 1.1446364, 'stdev_ref': 28.267727, 'range_ref': 499.98557, 'iqr_ref': 32.984161376953125}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r5r5
# 173254
# 44522
# Starting model saving process
# Save complete
# {'mse': 99.55658, 'mae': 6.0150113, 'medae': 4.0445094, 'max_error': 227.87263, 'bias': -0.28453207, 'r2': 0.8794452619980955, 'corr': 0.9378607950331334, 'cent_rmse': 9.97374647738764, 'stdev': 27.132175, 'amp_ratio': 0.76767796, 'stdev_ref': 28.737093, 'range_ref': 494.97427, 'iqr_ref': 31.19568634033203}
# {'mse': 173.75735, 'mae': 8.018121, 'medae': 5.444196, 'max_error': 456.16824, 'bias': 0.21312535, 'r2': 0.7782772854047718, 'corr': 0.8833802899442854, 'cent_rmse': 13.179971011273894, 'stdev': 25.989313, 'amp_ratio': 1.1769559, 'stdev_ref': 27.994085, 'range_ref': 499.97336, 'iqr_ref': 32.503135681152344}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r2r8
# 173284
# 44524
# Starting model saving process
# Save complete
# {'mse': 92.835045, 'mae': 5.9452496, 'medae': 4.051117, 'max_error': 234.1614, 'bias': -0.39164352, 'r2': 0.8828837103656217, 'corr': 0.9398306920510406, 'cent_rmse': 9.627131475823393, 'stdev': 26.863068, 'amp_ratio': 0.87814313, 'stdev_ref': 28.154469, 'range_ref': 487.33173, 'iqr_ref': 30.47760009765625}
# {'mse': 175.87097, 'mae': 8.0462265, 'medae': 5.425887, 'max_error': 377.5404, 'bias': 0.11381984, 'r2': 0.7785542339982008, 'corr': 0.883371158836949, 'cent_rmse': 13.26114999764199, 'stdev': 26.081678, 'amp_ratio': 1.3094629, 'stdev_ref': 28.181446, 'range_ref': 499.96906, 'iqr_ref': 32.35675048828125}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r3r7
# 173272
# 44505
# Starting model saving process
# Save complete
# {'mse': 93.35112, 'mae': 5.8400826, 'medae': 3.9746332, 'max_error': 261.84625, 'bias': -0.49533892, 'r2': 0.882650804656182, 'corr': 0.9396602851708645, 'cent_rmse': 9.649132197388445, 'stdev': 26.544662, 'amp_ratio': 0.8757547, 'stdev_ref': 28.204584, 'range_ref': 428.71182, 'iqr_ref': 31.29522705078125}
# {'mse': 164.11028, 'mae': 7.9946833, 'medae': 5.4740095, 'max_error': 439.09503, 'bias': 0.5059698, 'r2': 0.7823244046054827, 'corr': 0.8851317734267224, 'cent_rmse': 12.800561276067434, 'stdev': 25.077478, 'amp_ratio': 1.2077852, 'stdev_ref': 27.457636, 'range_ref': 499.9758, 'iqr_ref': 32.446014404296875}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r4r3
# 173251
# 44530
# Starting model saving process
# Save complete
# {'mse': 96.5775, 'mae': 5.9451256, 'medae': 3.9575753, 'max_error': 205.67937, 'bias': -0.27727032, 'r2': 0.8837682108229096, 'corr': 0.940155692148976, 'cent_rmse': 9.823472213673195, 'stdev': 26.937338, 'amp_ratio': 0.98423135, 'stdev_ref': 28.82541, 'range_ref': 464.38672, 'iqr_ref': 30.5233154296875}
# {'mse': 174.89178, 'mae': 8.166553, 'medae': 5.5568647, 'max_error': 401.78278, 'bias': 0.907707, 'r2': 0.7788040980144696, 'corr': 0.8840878125416193, 'cent_rmse': 13.193471321524482, 'stdev': 26.0408, 'amp_ratio': 1.2095721, 'stdev_ref': 28.118755, 'range_ref': 499.89227, 'iqr_ref': 32.557861328125}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r5r1
# 173244
# 44511
# Starting model saving process
# Save complete
# {'mse': 94.27852, 'mae': 5.9291425, 'medae': 3.9843178, 'max_error': 226.96501, 'bias': -0.2017541, 'r2': 0.8853530989150323, 'corr': 0.9409644011802195, 'cent_rmse': 9.707616474609866, 'stdev': 27.080355, 'amp_ratio': 0.8422425, 'stdev_ref': 28.67644, 'range_ref': 488.55527, 'iqr_ref': 31.156341552734375}
# {'mse': 168.61433, 'mae': 8.034001, 'medae': 5.4974785, 'max_error': 388.05853, 'bias': 0.52894664, 'r2': 0.7875555801928225, 'corr': 0.8881244127787916, 'cent_rmse': 12.974372564056862, 'stdev': 25.84532, 'amp_ratio': 1.2364998, 'stdev_ref': 28.172443, 'range_ref': 499.92862, 'iqr_ref': 33.142242431640625}
# Starting reconstruction saving process
# Save complete
# CanESM2
# r5r9
# 173253
# 44524
# Starting model saving process
# Save complete
# {'mse': 90.46671, 'mae': 5.9385023, 'medae': 3.998125, 'max_error': 220.19568, 'bias': 0.22355032, 'r2': 0.8869039070132159, 'corr': 0.94186663111298, 'cent_rmse': 9.508771525160718, 'stdev': 26.980686, 'amp_ratio': 0.863764, 'stdev_ref': 28.282682, 'range_ref': 448.36465, 'iqr_ref': 31.42157745361328}
# {'mse': 170.38416, 'mae': 8.046094, 'medae': 5.4990034, 'max_error': 405.2594, 'bias': 0.7306801, 'r2': 0.7836042681919867, 'corr': 0.8863116882242092, 'cent_rmse': 13.032658729057768, 'stdev': 25.868494, 'amp_ratio': 1.1045977, 'stdev_ref': 28.060175, 'range_ref': 499.98328, 'iqr_ref': 32.723114013671875}
# Starting reconstruction saving process
# Save complete
# 2023-07-01 04:57:11.482229

# %%
# Saving performance metrics and best parameters if optimization was carried out

approach_output_dir = f"{other_output_dir}/{approach}"
param_fname = f"{approach_output_dir}/{approach}_best_params_dict.pickle"
test_perform_fname = f"{approach_output_dir}/{approach}_test_performance_dict.pickle"
unseen_perform_fname = f"{approach_output_dir}/{approach}_unseen_performance_dict.pickle"

Path(approach_output_dir).mkdir(parents=True, exist_ok=True)

with open(param_fname, 'wb') as handle:
    pickle.dump(best_params, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(test_perform_fname, 'wb') as handle:
    pickle.dump(test_performance, handle)
with open(unseen_perform_fname, 'wb') as handle:
    pickle.dump(unseen_performance, handle)
    
# Convert performance metrics to dataframes
test_df = pd.DataFrame.from_dict({(i,j): test_performance[i][j]
                                  for i in test_performance.keys()
                                  for j in test_performance[i].keys()},
                                 orient='index')

unseen_df = pd.DataFrame.from_dict({(i,j): unseen_performance[i][j]
                                  for i in unseen_performance.keys()
                                  for j in unseen_performance[i].keys()},
                                 orient='index')

test_df.index.names = ["model","member"]
unseen_df.index.names = ["model","member"]

# Save the dataframes too
test_df_fname = f"{approach_output_dir}/{approach}_test_performance_df.pickle"
unseen_df_fname = f"{approach_output_dir}/{approach}_unseen_performance_df.pickle"

test_df.to_pickle(test_df_fname)
unseen_df.to_pickle(unseen_df_fname)

# %% [markdown]
# ### <font color='red'>Section III</font>
# #### Calculate pCO2 from the pCO2-Residual reconstructions

# %% [markdown]
# The pCO2-Residual is reconstructed in space and time. pCO2-T is now added back to pCO2-Residual to get pCO2

# %%
member_dir = "/data/artemis/workspace/theimdal/saildrone_5"
reference_output_dir = "/data/artemis/workspace/theimdal/saildrone/LET_pickle_files"

# pCO2-Residual reconstructions
run_dir = "/data/artemis/workspace/theimdal/saildrone_5/models/reconstructions/xg" 

# Loading references
path_LET = f"{reference_output_dir}/members_LET_dict.pickle"

with open(path_LET,'rb') as handle:
    mems_dict = pickle.load(handle)

# %%
for ens, mem_list in mems_dict.items():
    print(ens)
    # if ens =="CESM":
    #     mem_list = []
        
    for member in mem_list:
        
        member_dir = f"{run_dir}/{ens}/member_{member}" #run_dir = XGB reconstructions
        
        # File paths
        pco2D_path = f"{member_dir}/xg_recon_pC02_2D_mon_{ens}_{member}_1x1_198201-201701.nc" #pCO2-Residual reconstructions
        pco2T_path = f"/data/artemis/workspace/vbennington/LET/{ens}/pCO2_components_{ens}{member}_198201-201701.nc"  # pCO2-T is in this file, 
        file_out = f"{member_dir}/recon_pCO2DIC_pCO2_2D_mon_{ens}_{member}_1x1_198201-201701.nc" # Path for outputting pCO2 (pCO2-T added back to pCO2-Residual)
       
        if ens=="CanESM2":
            pco2T_path = f"/data/artemis/workspace/vbennington/LET/{ens}/pCO2_components_{ens}{member}_198201-201712.nc"  # pCO2-T in this file,
            
        # Load modeled pCO2-T and reconstructed pCO2-DIC:
        pco2T_series = xr.open_dataset(pco2T_path).pCO2_T.transpose("time","ylat","xlon") # pCO2-T calculated from model pCO2 and SST

        pco2D_series = xr.open_dataset(pco2D_path).pCO2_DIC_recon.transpose("time","ylat","xlon") # FULL reconstructed pCO2-Residual from XGB
        
        pco2D_unseen_series = xr.open_dataset(pco2D_path).pCO2_DIC_nosocat.transpose("time","ylat","xlon") # UNSEEN reconstructed pCO2-Residual from XGB
        
        # Get time coordinate correct
        pco2T_series = pco2T_series.assign_coords({"time":("time",pco2D_series.time)})
        
        pco2_series = pco2T_series + pco2D_series     # Total pCO2 =  pCO2-DIC + pCO2-T
        
        pco2_nosocat =  pco2T_series + pco2D_unseen_series
        
        comp = xr.Dataset({
                        'pCO2_DIC_recon':(["time","ylat","xlon"],pco2D_series), #FULL pCO2-Residual reconstruction
                        'pCO2_full_recon':(["time","ylat","xlon"],pco2_series), #FULL pCO2 reconstruction
                        'pCO2_DIC_nosocat_recon':(["time","ylat","xlon"],pco2D_unseen_series), #UNSEEN pCO2-Residual reconstruction
                        'pCO2_nosocat_recon':(["time","ylat","xlon"],pco2_nosocat), #UNSEEN pCO2 reconstruction
                        'pCO2_T':(["time","ylat","xlon"],pco2T_series)},        #pCO2T = temp driven component of pCO2
                        coords={'time': (['time'],pco2T_series.time.values),
                        'ylat': (['ylat'],pco2T_series.ylat.values),
                        'xlon':(['xlon'],pco2T_series.xlon.values)})

        # if os.path.isfile(file_out):
        #     os.remove(file_out)
        
        # comp.to_netcdf(f"{file_out}")
        comp.to_netcdf(f'/data/artemis/workspace/theimdal/saildrone/TEST/recon_pCO2_unseen_2D_mon_{ens}_{member}_1x1_198201-201701.nc')
        
        del pco2T_path, pco2D_path, pco2_series, pco2T_series, pco2D_series
